# %%
#Data Manipulation
import pandas as pd
data={'Name':["Alok","Bhanu","Yash","Raj","Akshay","Saheli"],'Age':[32,30,30,30,23,28],'City':["Pune","Kolkata","Patna","Chennai","Aligarh","Bhubhaneswar"]}
df=pd.DataFrame(data)
df
# Out:
#      Name  Age          City
# 0    Alok   32          Pune
# 1   Bhanu   30       Kolkata
# 2    Yash   30         Patna
# 3     Raj   30       Chennai
# 4  Akshay   23       Aligarh
# 5  Saheli   28  Bhubhaneswar

# %%
#Filter data based on condition
df_updated=df[df['Age']>28]
print("Data filtered by Age: ",df_updated)
#Data Sorting by Age
df_age=df.sort_values(by='Age',ascending=True)
print("Data sorted by Age: ",df_age)
#Group Data by City and calculate avergae age
df_group=df['Age'].mean()
print("Mean of the Data by Age: ",df_group)
# Out:
# Data filtered by Age:      Name  Age     City
# 0   Alok   32     Pune
# 1  Bhanu   30  Kolkata
# 2   Yash   30    Patna
# 3    Raj   30  Chennai
# Data sorted by Age:       Name  Age          City
# 4  Akshay   23       Aligarh
# 5  Saheli   28  Bhubhaneswar
# 1   Bhanu   30       Kolkata
# 2    Yash   30         Patna
# 3     Raj   30       Chennai
# 0    Alok   32          Pune
# Mean of the Data by Age:  28.833333333333332

# %%
p=pd.Series((4,5,6))
print("Series without index: ",p)
p_i=pd.Series((4,5,6),index=("Ikka","Begum","Baadshah"))
print("Series with index: ",p_i)
# Out:
# Series without index:  0    4
# 1    5
# 2    6
# dtype: int64
# Series with index:  Ikka        4
# Begum       5
# Baadshah    6
# dtype: int64
